# %%
# Import section
import pandas as pd
import numpy as np
import zipfile
import requests
from io import BytesIO

# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge firefox geckodriver
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/mohjaiswal/opt/anaconda3
#
#   added / updated specs:
#     - firefox
#     - geckodriver
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     firefox-109.0              |       hf0c8a7f_0       102.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       102.8 MB
#
# The following packages will be UPDATED:
#
#   firefox                                108.0.2-hf0c8a7f_0 --> 109.0-hf0c8a7f_0
#
#
#
# ...
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# ERROR conda.core.link:_execute(740): An error occurred while uninstalling package 'conda-forge/osx-64::firefox-108.0.2-hf0c8a7f_0'.
# Rolling back transaction: done
#
# ...

# %%
# Using the read_csv function and Path module, create a DataFrame 
# by importing the sfo_neighborhoods_census_data.csv file from the Resources folder
asset_data_df = requests.get("https://www150.statcan.gc.ca/n1/tbl/csv/46100062-eng.zip")

# %%
with zipfile.ZipFile(BytesIO(asset_data_df.content)) as zip_file:
# Extract the file by name
    csv_file = '46100062.csv'
    with zip_file.open(csv_file) as csv_file_opened:
        home_prices_df = pd.read_csv(csv_file_opened, header=0, sep=',', quotechar='"')

# %%
# Review the first and last five rows of the DataFrame
display(home_prices_df.head(),home_prices_df.tail())
# Out:
#    REF_DATE          GEO        DGUID  \
# 0      2018  Nova Scotia  2016A000212
# 1      2018  Nova Scotia  2016A000212
# 2      2018  Nova Scotia  2016A000212
# 3      2018  Nova Scotia  2016A000212
# 4      2018  Nova Scotia  2016A000212
#
#   Number of buyers as part of a property sale             Age groups  \
# 0      Total, all number of buyers categories  Total, all age groups
# 1      Total, all number of buyers categories  Total, all age groups
# 2      Total, all number of buyers categories  Total, all age groups
# 3      Total, all number of buyers categories  Total, all age groups
# 4      Total, all number of buyers categories  Total, all age groups
#
#         First-time home buyer status  \
# 0  Total, all home buyers categories
# 1  Total, all home buyers categories
# 2  Total, all home buyers categories
# 3  Total, all home buyers categories
# 4  Total, all home buyers categories
#
#                          Buyer characteristics  \
# ...
