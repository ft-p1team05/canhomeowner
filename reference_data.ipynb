# %%
import pandas as pd

# %%
df = pd.read_csv("46100062-eng/46100062.csv")

# %%
df.tail()
# Out:
#           REF_DATE                              GEO             DGUID  \
# 17795707      2019  Yukon, Unorganized, Unorganized  2016A00056001045
# 17795708      2019  Yukon, Unorganized, Unorganized  2016A00056001045
# 17795709      2019  Yukon, Unorganized, Unorganized  2016A00056001045
# 17795710      2019  Yukon, Unorganized, Unorganized  2016A00056001045
# 17795711      2019  Yukon, Unorganized, Unorganized  2016A00056001045
#
#          Number of buyers as part of a property sale             Age groups  \
# 17795707           Buyer in a group of three or more  55 years old and over
# 17795708           Buyer in a group of three or more  55 years old and over
# 17795709           Buyer in a group of three or more  55 years old and over
# 17795710           Buyer in a group of three or more  55 years old and over
# 17795711           Buyer in a group of three or more  55 years old and over
#
#          First-time home buyer status  \
# 17795707    Not first-time home buyer
# ...

# %%
df.count()
# Out:
# REF_DATE                                       17795712
# GEO                                            17795712
# DGUID                                          17702784
# Number of buyers as part of a property sale    17795712
# Age groups                                     17795712
# First-time home buyer status                   17795712
# Buyer characteristics                          17795712
# Estimates                                      17795712
# UOM                                            17795712
# UOM_ID                                         17795712
# SCALAR_FACTOR                                  17795712
# SCALAR_ID                                      17795712
# VECTOR                                         17795712
# COORDINATE                                     17795712
# VALUE                                           4292962
# STATUS                                         15287035
# SYMBOL                                                0
# ...

# %%
df2 = pd.read_csv("10100006-eng/10100006.csv")

# %%
df2.count()
# Out:
# REF_DATE           12036
# GEO                12036
# DGUID              12036
# Components         12036
# Unit of measure    12036
# UOM                12036
# UOM_ID             12036
# SCALAR_FACTOR      12036
# SCALAR_ID          12036
# VECTOR             12036
# COORDINATE         12036
# VALUE               9600
# STATUS              2436
# SYMBOL                 0
# TERMINATED             0
# DECIMALS           12036
# dtype: int64

# %%
df2.head()
# Out:
#   REF_DATE     GEO           DGUID  \
# 0  2013-01  Canada  2016A000011124
# 1  2013-01  Canada  2016A000011124
# 2  2013-01  Canada  2016A000011124
# 3  2013-01  Canada  2016A000011124
# 4  2013-01  Canada  2016A000011124
#
#                                           Components Unit of measure      UOM  \
# 0  Total, funds advanced, residential mortgages, ...         Dollars  Dollars
# 1  Total, funds advanced, residential mortgages, ...   Interest rate  Percent
# 2  Variable rate, funds advanced, residential mor...         Dollars  Dollars
# 3  Variable rate, funds advanced, residential mor...   Interest rate  Percent
# 4  Fixed rate, funds advanced, residential mortga...         Dollars  Dollars
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID      VECTOR COORDINATE    VALUE STATUS  \
# 0      81      millions          6  v122667724      1.1.1  5880.00    NaN
# 1     239        units           0  v122667775      1.1.2     3.23    NaN
# ...

# %%
df3 = pd.read_csv("34100133-eng/34100133.csv")
# Out:
# C:\Users\keito\anaconda3\envs\dev\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df3.count()
# Out:
# REF_DATE             119032
# GEO                  119032
# DGUID                118148
# Type of structure    119032
# Type of unit         119032
# UOM                  119032
# UOM_ID               119032
# SCALAR_FACTOR        119032
# SCALAR_ID            119032
# VECTOR               119032
# COORDINATE           119032
# VALUE                 64457
# STATUS                54575
# SYMBOL                    0
# TERMINATED             2552
# DECIMALS             119032
# dtype: int64

# %%
df3.head()
# Out:
#    REF_DATE                                     GEO         DGUID  \
# 0      1987  Bay Roberts, Newfoundland and Labrador  2011S0504005
# 1      1987  Bay Roberts, Newfoundland and Labrador  2011S0504005
# 2      1987  Bay Roberts, Newfoundland and Labrador  2011S0504005
# 3      1987  Bay Roberts, Newfoundland and Labrador  2011S0504005
# 4      1987  Bay Roberts, Newfoundland and Labrador  2011S0504005
#
#                                    Type of structure         Type of unit  \
# 0  Row and apartment structures of three units an...       Bachelor units
# 1  Row and apartment structures of three units an...    One bedroom units
# 2  Row and apartment structures of three units an...    Two bedroom units
# 3  Row and apartment structures of three units an...  Three bedroom units
# 4             Row structures of three units and over       Bachelor units
#
#        UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE  VALUE  \
# ...
